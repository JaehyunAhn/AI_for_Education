# %% [markdown]
# <a href="https://colab.research.google.com/github/JaehyunAhn/AI_for_Education/blob/master/pdf_extraction_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 36.5 MB/s eta 0:00:00
# ...

# %%
import fitz
import pandas as pd

# %%
doc = fitz.open('./sample_data/table.pdf')

for page in doc:
  print(page.get_text())
  break
# Out:
# Example table
# This is an example of a data table.
# Disability
# Category
# Participants
# Ballots
# Completed
# Ballots
# Incomplete/
# Terminated
# Results
# Accuracy
# Time to
# complete
# Blind
# 5
# 1
# 4
# 34.5%, n=1
# 1199 sec, n=1
# Low Vision
# 5
# 2
# 3
# 98.3% n=2
# (97.7%, n=3)
# 1716 sec, n=3
# (1934 sec, n=2)
# Dexterity
# 5
# 4
# 1
# 98.3%, n=4
# 1672.1 sec, n=4
# Mobility
# 3
# 3
# 0
# 95.4%, n=3
# 1416 sec, n=3

# %%
for page in doc:
  tabs = page.find_tables()
  if len(tabs.tables) > 0:
    print(len(tabs.tables))
    print(tabs[0])
    break
# Out:
# 1
# ...

# %%
tabs[0].header.names
# Out:
# ['',
#  None,
#  None,
#  '',
#  None,
#  None,
#  '',
#  None,
#  None,
#  '',
#  None,
#  None,
#  '',
#  'Results',
#  None,
#  None,
#  None,
#  '']

# %%
df = tabs[0].to_pandas()
df
# Out:
#           Col0        Col1  Col2  Col3          Col4  Col5  Col6       Col7  \
# 0         None        None  None  None          None  None  None       None
# 1               Disability        None          None  None          Ballots
# 2         None        None  None        Participants        None       None
# 3         None    Category  None  None          None  None  None  Completed
# 4         None        None  None  None          None  None  None       None
# 5         None        None  None  None          None  None  None       None
# 6         None        None  None                None  None  None       None
# 7                     None  None  None          None  None             None
# 8         None        None  None  None          None  None  None       None
# 9        Blind        None  None     5          None  None     1       None
# 10  Low Vision        None  None     5          None  None     2       None
# ...

# %%
df.shape
# Out:
# (13, 18)

# %%
df.columns
# Out:
# Index(['please re-consider applying for a\nloan of a different amount that may\nbetter align with your income.'], dtype='object')
